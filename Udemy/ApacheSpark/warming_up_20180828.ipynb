# %% [markdown]
# - jdk
# - spark
# - scala IDE

# %% [markdown]
# - import jars in spark on scala IDE
# - fix scala to spark version
# - change jvm

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # What is Spark?

# %% [markdown]
# - driver program : spark context
# - cluster manager ( spark, yarn )
#   - executor
#   - executor
# - code in python, java or scala
# - Built around one main concept : the resollient distributed dataset(RDD)
# - spark streaming, spark SQL, MLLib, GraphX

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# - Why Scala?
#   - best performance
#   - simplest codes

# %% [markdown]
# # Resillient Distributed Dataset

# %% [markdown]
# - Create RDD
# - Transforming RDD
#   - map
#   - flatmap
#   - filter
#   - distinct
#   - sample
#   - union, intersection, subtract, cartesian

# %% [markdown]
# - RDD Actions
#   - collect
#   - count
#   - countByValue
#   - take
#   - top
#   - reduce

# %% [markdown]
# # Ratings Counter programs

# %% [markdown]
# # Spark Internals

# %% [markdown]
# # Key / Value RDD's
