# %% [markdown]
# # Spring in a Nutshell

# %% [markdown]
# - J2EE
#     - client-size presentation
#     - server side presentation
#     - server-side business logic
#     - database

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# - J2EE development without EJB
#     - Rod Johnson
#         - Rounder of Spring

# %% [markdown]
# # Why Spring?

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# - Spring
# - Java EE
#
# Both

# %% [markdown]
# - Spring 5
#     - Java 8 or higher

# %% [markdown]
# # Spring Core Framework

# %% [markdown]
# - www.spring.io

# %% [markdown]
# - Simplify Java Enterprise Development
# - Goals of Spring
#     - lightweight development with Java POJO
#     - Dependency injection ot promote lose coupling
#     - Declarative programming with Aspect Oriented Programming
#     - Minimize boilerplace code

# %% [markdown]
# - core container
#     - Beans
#     - Core
#     - SpEL
#     - Context

# %% [markdown]
# - Infrastructure
#     - AOP : logging, security, transactions
#     - Aspects :
#     - Instrumentation
#     - Messaging
#
# - Data Access Layer
#     - JDBC
#     - ORM integration with Hibernate or JSP
#     - Transactions
#     - OXM or JMS

# %% [markdown]
# - Web Layer
#     - Servlet
#     - WebSocket
#     - Web
#     - Portiet

# %% [markdown]
# - Test Layer
#     - Unit
#     - Integration
#     - Mock

# %% [markdown]
# # Spring Platform

# %% [markdown]
# - Additional Spring modules built-in top of the core Spring Framework
#     - Spring Cloud, Spring Data
#     - Spring Batchm Spring Security
#     - Spring for Android, Spring Web Flow
#     - Spring Web Services, Spring LDAP

# %% [markdown]
# # Dev Environment Overview

# %% [markdown]
# - Software
# - High level Steps

# %% [markdown]
# - JDK
