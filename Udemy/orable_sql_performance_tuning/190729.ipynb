# %% [markdown]
# # Reading Execution Plan

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# - CPU_COST : No of CPU cycle
# - DEPTH :
# - IO_COST
# - OBJECT_OWNER
# - OBJECT_TYPE
# - OPTH
#     - cost based optimization
#     - rule based optimization : old technique

# %% [markdown]
# # Analyzing the Execution Plans

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# - Too much resource on Id 6 ~ 8 and it might be from the IN condition

# %% [markdown]
# ```sql
# SELECT p.prod_d
#     , p.prod_name
#     , s.amount_sold
#     , s.quantity_sold
# FROM sales s, products p, customers c
# WHERE s.prod_id = p.prod_id
#     AND s.cust_id = c.cust_id
#     AND s.cust_id BETWEEN 2 AND 5
# ```

# %% [markdown]
# - Where to look?
#     - Cost
#     - Access Methods
#     - Cardinality
#     - Join Methods & Join Types
#     - Partition Pruning
#     - Others : Views, cotation ..

# %% [markdown]
# # Table & Index Access Paths

# %% [markdown]
# - indexes are the most important key on performance tuning
#
# - Types of Indexes
#     - B-TREE Indexes
#         - Normal index
#         - function based index
#         - index-orgranized table (IOT)
#     - Bitmap Indexes
#
# - Attributes of Indexes
#     - Key Compression
#     - Reverse Key
#     - Ascending - Descending Ordered Indexes

# %% [markdown]
# B-TREE
# ![image.png](attachment:image.png)

# %% [markdown]
# BITMAP
# ![image.png](attachment:image.png)

# %% [markdown]
# - You can use a bitmap join indexes bitmap join indexes are used for multiple tables with joins so often

# %% [markdown]
# # Types of Table and Index Access Paths

# %% [markdown]
# - Which access path is better in which circumstances?
# - table access Paths : reading the whole table is more effective on low selectivity
# - index access paths
