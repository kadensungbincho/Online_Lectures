# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# - Oracle Database

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# - User Processes

# %% [markdown]
# # Oracle Database Architecture Overview

# %% [markdown]
# # Database Data Block

# %% [markdown]
# - All the data is stored in blocks
# - A block is the smallest unit of database storage
# - A block can have 2KB to 32KB size
# - A block stores row data or index data
# - Block Header inlcudes

# %% [markdown]
# - we can use PCTFREE or PCTUSE params to specify the space size in blocks

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# - Session Memory
# - Private SQL
# - Cursor
# - SQL Work

# %% [markdown]
# - Size of PGA is important

# %% [markdown]
# # Shared Pool Detail

# %% [markdown]
# - data dictionary cache
