// %% [markdown]
// - Getting started
//   - intall dependencies per operating system
//   - install eslint depending on code editor
//   - generate a react native project
//   - get coding
//
// - First app
//   - purpose of react native
//   - components
//   - state
//   - props

// %% [markdown]
// ![image.png](attachment:image.png)
