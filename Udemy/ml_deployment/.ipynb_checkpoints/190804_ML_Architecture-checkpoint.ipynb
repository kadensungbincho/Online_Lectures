# %% [markdown]
# # Why it matters

# %% [markdown]
# - Infra
# - Applications
# - Data
# - Documentation
# - Configuration and more

# %% [markdown]
# # Challengs

# %% [markdown]
# - Reproducibility
# - Engtanglement
# - Data Dependencies
# - Configuration
# - Data and feature preparation
# - model error : hart to detect
# - Separation of expertise

# %% [markdown]
# # Degisn Approach

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # Architecture Component Breakdown

# %% [markdown]
# sugimura and harti

# %% [markdown]
# # Building a reproducible machine learning pipeline

# %% [markdown]
# # Procedural Programming

# %% [markdown]
# # Designing custom pipeline
