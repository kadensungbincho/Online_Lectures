# %% [markdown]
# # Spark vs Flink

# %% [markdown]
# - Check point

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # Flink Architecture & Eco System

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # Flow of a Flink Program

# %% [markdown]
# - DataSet
#     - Immutable
#     - Does not support individual operations
#     - Stores list of it's dependencies

# %% [markdown]
# # WorkCount with groupBy, Filter, Map

# %% [markdown]
# - readTextFile
# - readCsvFile
# -

# %% [markdown]
# ```java
# public static final classMyFilter implements FilterFunction {
#     public void filter() {
#     }
# }
# ```

# %% [markdown]
# ```bash
# ./bin/flink run /home/kaden.cho/wc2.jar --input file:///home/kaden.cho/wc.txt --output file:///home/kaden.cho/wordcount_out
# ```
