# %% [markdown]
# # Services

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ```bash
# 10010  minikube start
# 10011  kubectl get all
# 10012  kubectl apply -f first-pod.yaml
# 10013  kubectl apply -f webapp-service.yaml
# 10014  kubectl get all
# 10015  kubectl
# 10016  kubectl ip
# 10017  history | grep kubectl
# 10018  history | grep ip
# 10019  minikube ip
# 10020  clear
# 10021  jubectl get all
# 10022  kubectl get all
# 10023  kubectl describe pod queue
# 10024  git status
# 10025  git add --all
# 10026  git commit -m "Update"
# 10027  git push origin master
# 10028  kubectl describe svc fleetman-webapp
# 10029  ls
# 10030  kubectl apply -f webapp-service.yaml
# 10031  ls
# 10032  kubectl get all
# 10033  kubectl describe svc fleetman-webapp
# 10034  ls
# 10035  kubectl delete po webapp-release-0-5
# 10036  ls
# 10037  kubectl get all
# 10038  ls
# 10039  clear
# 10040  there some safety reason
# 10041  core api
# 10042  experimental feature
# 10043  ls
# 10044  kubectl apply -f pods.yaml
# 10045  ls
# 10046  kubectl
# 10047  kubectl get all
# 10048  kubectl deelete po -all
# 10049  kubectl delete po -all
# 10050  kubectl delete po -a
# 10051  kubectl delete po --a
# 10052  kubectl delete po --all
# 10053  kubectl apply -f pods.yaml
# 10054  kubectl get all
# 10055  kubectl describe replicaset webapp
# 10056  kubectl describe rs webapp
# 10057  kubectl apply -f services.yaml
# 10058  ls
# 10059  kubectl get all
# 10060  ls
# 10061  kubectl delete po webapp-zkswr
# 10062  kubectl get all
# 10063  ls
# 10064  kubectl apply -f pods.yaml
# 10065  kubectl get all
# 10066  kubectl desribe rs webapp
# 10067  kubectl describe rs webapp
# 10068  kubectl get all
# 10069  kubectl delete po webapp-n2xlg
# 10070  kubectl get all
# 10071  separate concept of the file
# 10072  ls
# 10073  kubectl get all
# 10074  kubectl delete rs webapp
# 10075  kubectl get all
# 10076  kubectl apply -f pods.yaml
# 10077  kubectl get all
# 10078  ls
# 10079  for that reaso
# 10080  for that  \n\ne
# 10081  ls
# 10082  kubectl apply -f pods.yaml
# 10083  kubectl get all
# 10084  jubectl rollout statu
# 10085  kubectl rollout status
# 10086  kubectl rollout status webapp
# 10087  kubectl rollout status deployment webapp
# 10088  kubectl apply -f pods.yaml
# 10089  kubectl rollout status deployment webapp
# 10090  kubectl rollout history deploy webapp
# 10091  kubectl rollout undo deploy webapp
# ```

# %% [markdown]
# ![image.png](attachment:image.png)
