# %% [markdown]
# - Minikube

# %% [markdown]
# # Intro Kubernetes

# %% [markdown]
# - Container Orchestration Systems

# %% [markdown]
# - Too many docker container system to manage

# %% [markdown]
# # Hands on project

# %% [markdown]
# # Setting up

# %% [markdown]
# # Pods Overview

# %% [markdown]
# - Pod is wrapper for a container
# - one to one relationship
#     - Why extra jargon?
#         - can put 2 containers in a pod
#         - there're some exceptions
#             - microservice + helper container (logs collector)
#     -

# %% [markdown]
# # Writing a Pod

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# - Pods is not intended to be visible from the outside

# %% [markdown]
# ```bash
# 10005  brew install kubernetes-cli
# 10006  kubectl version
# 10007  brew cask install minikube
# 10008  minikube start --vm-driver=virtualbox
# 10009  ls
# 10010  vim ~/.docker/config.json
# 10011  minikube start --vm-driver=virtualbox
# 10012  kubectl version
# 10013  minikube stop
# 10014  minikube start
# 10015  minikube status
# 10016  ls
# 10017  cd ~/git/kadensungbincho
# 10018  ls
# 10019  cd Online_Lectures/Udemy
# 10020  ls
# 10021  cd kubernetes_hands_on_deploy_microservice
# 10022  ls
# 10023  vim first-pod.yaml
# 10024  ls
# 10025  vim first-pod.yaml
# 10026  ls
# 10027  kubectl get all
# 10028  kubectl apply -f first-pod.yaml
# 10029  kubectl get all
# 10030  minukube ip
# 10031  minikube ip
# 10032  kubectl describe pod webapp
# ```

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # Services
