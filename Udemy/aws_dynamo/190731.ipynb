# %% [markdown]
# # Intro

# %% [markdown]
# # What is Dynamo DB?

# %% [markdown]
# - fully managed cllous database
# - Seamless on-demand scaling
# - unlimited concurrent read/write operations
# -  single-digit millisecond latency
# - sub-microsecond latency with DAX

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# - little to no learning curve
# - best practices - crucial to success

# %% [markdown]
# # Environment Setup

# %% [markdown]
# - setup aws api user
# - install node.js
# - install editor

# %% [markdown]
# # Types of NoSQL Databases

# %% [markdown]
# - columnar database
# - key-value
# - graph database
# - document database

# %% [markdown]
# # Overview of Dynamo

# %% [markdown]
# -
