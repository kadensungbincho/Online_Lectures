# %% [markdown]
# # Introduction to Connecting the to Internet

# %% [markdown]
# # Dial-up, Modems and Point-to-Point Protocols

# %% [markdown]
# - Baud rate : A measurement of how many bits can be passed across a phone line in a second

# %% [markdown]
# # What is broadband?

# %% [markdown]
# - T-carrier techinologies : Originally invented by AT&T in order to transmit multiple phone calls over a single link

# %% [markdown]
# - DSL ( digital subscriber lines) :
# - Cable Broadband
# - Fiber Connection

# %% [markdown]
# # Cable Broadband

# %% [markdown]
# - Cable modem
# - Cable model termination system : Connects lots of different cable connections to an ISPs core network

# %% [markdown]
# # Fiber connections

# %% [markdown]
# - FTTN : fiber to the neighbor
# - Optical Network Terminator : Converts data from portocols the fiber network can understand, to those that more traditional, twisted-pair copper networks can understand

# %% [markdown]
# # Wide Area Network Technologies

# %% [markdown]
# - demarcation point
# - LEC or ISP

# %% [markdown]
# # Point-to-Point VPNs

# %% [markdown]
# # Introduction to Wireless Networking Technologies

# %% [markdown]
# - Frequency band : A certain section of the radio spectrum that's been agreed upon to be used for certain communications

# %% [markdown]
# - WiFi on 2.4Ghz and 5Ghz

# %% [markdown]
# - 802.11 = physical and data link layers

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# - Wireless access point : A device that bridges the wireless and wired portions of a network

# %% [markdown]
# # Wireless Network Configurations

# %% [markdown]
# - Ad hoc network :
# - wireless LANS
# - Mesh Network

# %% [markdown]
# # Wireless Channels

# %% [markdown]
# - Channels : individual, smaller sections of the overall frequency band used by a wireless network
# - Collision domain : Any one network segment where one computer can interrupt another

# %% [markdown]
# # Wireless Security

# %% [markdown]
# - Wired Equivalent Privacy : An encryption technology that provides a very low level of privacy

# %% [markdown]
# - WPA2 : 256 bits
# - MAC filtering : You configure your access points to only allow for connections from a specific set of MAC addresses belonging to devices you trust

# %% [markdown]
# # Cellular Networking
