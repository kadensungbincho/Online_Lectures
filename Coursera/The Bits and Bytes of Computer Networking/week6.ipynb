# %% [markdown]
# # Introduction to Troubleshooting and the Future of Networking

# %% [markdown]
# - Error Detection : The ability for a protocol or program to determine that something went wrong

# %% [markdown]
# # Ping : Internet Control Message Protocol

# %% [markdown]
# - ICMP : Internet Control Message Protocol

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# - Ping lets you send a special type of ICMP message called an Echo Request. If the destination is up and running and able to communicate on the network, it'll send back an ICMP Echo Reply message type.

# %% [markdown]
# # Traceroute

# %% [markdown]
# - A utility that lets you discover the path between two nodes, and gives you information about each hop along the way

# %% [markdown]
# - mtr on Linux and Mac
# - pathping on Window

# %% [markdown]
# # Testing Port Connectivity

# %% [markdown]
# - Check transport layer

# %% [markdown]
# - netcat - Linux / MacOS
# - Test-NetConnection - Window

# %% [markdown]
# - nc -z -v [ip] [port]

# %% [markdown]
# # Name Resolution Tools

# %% [markdown]
# - nslookup

# %% [markdown]
# # Public DNS Servers

# %% [markdown]
# - An ISP almost always gives you access to a recursive name server as part of the service it provides

# %% [markdown]
# - Public DNS Servers : Name servers specifically set up so that anyone can use them, for free

# %% [markdown]
# - Most public NDS servers are available globally through anycast.

# %% [markdown]
# - Always make sure the name server is run by a reputable company, and try to use the name servers provided by your ISP outside of troubleshooting scenarios

# %% [markdown]
# # DNS Registration and Expiration

# %% [markdown]
# - Registrar : An organizaion responsible for assigning individual domain names to other organizations or individuals

# %% [markdown]
# # Hosts Files

# %% [markdown]
# - The original way that numbered network addresses were correlated with words was through hosts files

# %% [markdown]
# - Hosts File : A flat file that contains, on each line, a network address followed by the host name it can be referred to as

# %% [markdown]
# - Loopback Address : A way of sending network traffic to yourself

# %% [markdown]
# - the loopback ip for ipv4 is 127.0.0.1

# %% [markdown]
# - Almost every hosts file in existence will, in the very least, contain a line that reads 127.0.0.1 localhiost, most likely followed by::1 localhost, where ::1 is the loopback address for IPv6

# %% [markdown]
# - hosts files are a popular way for computer viruses to disrupt and redirect user's traffic

# %% [markdown]
# # What is the cloud?

# %% [markdown]
# - Cloud Computing : A technologyical approach where computing resources are provisioned in a shareable way, so that lots of users get what they need, when they need it

# %% [markdown]
# - Hardware Virtualization
# - Virtualization : A single physical machine, called a host, could run many individual virtual instances, called guests

# %% [markdown]
# - Hypervisor : A piece of software that runs and manages virtual machines, while also offering these guests a virtual operating platform that's indistinguishable from actual hardware

# %% [markdown]
# - Private Cloud

# %% [markdown]
# # Everything as a Service
