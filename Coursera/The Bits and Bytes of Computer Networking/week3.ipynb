# %% [markdown]
# # The Transport Layer
# - multiplexing, demultiplexing
# - TCP, UDP, 3-ways handshake
# - multiplexing : nodes on the network have the ability to direct traffic toward many different receiving services
# - demultiplexing : receiving from many other sources
# - port : 16-bit number that's used to direct

# %% [markdown]
# # Dissection of a TCP Segment

# %% [markdown]
# - TCP : TCP header, data section

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# - Destination port : the port of the service is headed for
# - Source port

# %% [markdown]
# - Sequence Number : a 32-bit number that's used to keep track of where in a sequence of TCP segments this one is expected to be

# %% [markdown]
# - limited in size to 1,518 bytes in Ethernet frame

# %% [markdown]
# - Acknowledgement number : the number of the next expected segment

# %% [markdown]
# - Data offset field : A 4-bit number that communicates how long the TCP header for this segment is

# %% [markdown]
# - Control flags :
# - TCP window : specifes the range of sequence numbers that might be sent before an acknowledgement is required

# %% [markdown]
# - TCP checksum : operates just like the checksum fields at the IP and ethernet level
#     - the checksum is calculated across the entire segment and is compared with the checksum in the header to make sure that there was no data lost or corrupted along the way

# %% [markdown]
# - Urgent pointer field : used in conjunction with one of the TCP control flags to point out particular segments that might be more important than others

# %% [markdown]
# - options fields : it is sometimes used for more complicated flow control protocols

# %% [markdown]
# - Padding :

# %% [markdown]
# # TCP Control Flags and the Three-way Handshake

# %% [markdown]
# - URG(urgent) :  A value of one here indicates that the segment is considered urgent and that the urgent pointer field has more data about this
# - ACK(acknowledged) : A value of one in this field means that the acknowledgement number field should be examined
# - PSH(push) : The transmitting device wants the receiving device to push currently-buffered data to the application on the receiving end as soon sa possible
# - RST(reset) : One of the sides in a TCP connection hasn't been able to properly recover from a series of missing or malformed segments
# - SYN(synchronize) : It's used when first establishing a TCP connection and makes sure the receiving end knows to examine the sequence number field
# - FIN(finish) : When the flag is set to one, it means the transmitting computer doesn't have any more data to send and the connection can be closed

# %% [markdown]
# # TCP Socket States

# %% [markdown]
# - socket : The instantiation of an end-point in a potential TCP connection
# - Instantiation : The actual implementation of something defined elsewhere

# %% [markdown]
# - socket states
#     - LISTEN : A TCP socket is ready and listening for incoming connections (server side only)
#     - SYN_SENT : A synchronization request has been sent, but the connection hasn't been established yet (client side only)
#     - SYN_RECEIVED : A socket previously in a LISTEN state has received a synchronization request and sent a SYN/ACK back (server side only)
#     - ESTABLISHED : The TCP connection is in working order and both sides are free to send each other data
#     - FIN_WAIT : A FIN has been sent, but the corresponding ACK from the other end hasn't been received yet
#     - CLOSED_WAIT : The connection has been closed at the TCP layer, but that the application that opened the socket hasn't released its hold on the socket yet
#     - CLOSED : The connection has been fully terminated and the no further communication is possible

# %% [markdown]
# # Connection-oriented and Connectionless Protocols

# %% [markdown]
# - Establishes a connection, and uses this to ensure that all data has been properly transmitted

# %% [markdown]
# - Unlike TCP, UDP doesn't depend on connections and it doesn't even support the concept of an acknowledgment. With UDP, you just set a destination port and send the packet.

# %% [markdown]
# # Firewalls

# %% [markdown]
# - A device that blocks traffic that meets certain criteria

# %% [markdown]
# # The Application Layer

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# - Payload

# %% [markdown]
# - HTTP Protocol

# %% [markdown]
# # The Application Layer and OSI Model

# %% [markdown]
# - OSI model introduces two more layers betweeen tranport and application layer : session, presentation
#     - session layer : facilitating the communication between actual applications and the transport layer. Takes application layer data and hands it off to the presentation layer
#     - presentation layer : responsible for making sure that the unencapsulated application layer data is able to be understood by the application in question

# %% [markdown]
# # All the Layers Working in Unison
