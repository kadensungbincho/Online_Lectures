# %% [markdown]
# ```
# >>> readme = sc.textFile("file:///root/spark/README.md")
# >>> readme.filter(lambda line: "Spark" in line).count()
# ```

# %% [markdown]
# ```
# rdd = sc.textFile("s3n://AWS_ACCESS_KEY_ID:AWS_SECRET_ACCESS_KEY@BUCKET_NAME/gutenberg_dataset/1/8/*/*")
# rdd = sc.wholeTextFiles("s3n://AWS_ACCESS_KEY_ID:AWS_SECRET_ACCESS_KEY@BUCKET_NAME/gutenberg_dataset/1/8/*/*")
# ```

# %% [markdown]
# - url invalid [error with / character on AWS_SECRET_ACCESS_KEY or AWS_ACCESS_KEY_ID](https://stackoverflow.com/questions/3009792/problem-with-copying-local-data-onto-hdfs-on-a-hadoop-cluster-using-amazon-ec2/3033403#3033403)

# %% [markdown]
# ```
# rdd = sc.textFile("s3n://kadenchocluster/gutenberg_dataset/1/8/0/1804/1804.txt")
# >>> rdd.take(!)
#   File "<stdin>", line 1
#     rdd.take(!)
#              ^
# SyntaxError: invalid syntax
# >>> rdd.take(1)
# ['The Project Gutenberg EBook of War and the Future, by H. G. Wells']
# >>> rdd.filter(lambda line : "mankind" in line).count()
# 34
# >>> rdd.filter(lambda line : "mankind" in line).saveAsTextFile("s3n://kadenchocluster/result/lesson_2-2")
# 18/08/02 15:28:36 WARN RestStorageService: Retrying request following error response: PUT '/result_$folder$' -- ResponseCode: 307, ResponseStatus: Temporary Redirect, Request Headers: [Date: Thu, 02 Aug 2018 15:28:36 GMT, Content-Type: binary/octet-stream, Authorization: AWS AKIAJOR7UDIQII6UEAOA:mZRfdMbR035DBXV/62f1v6elD2o=, Host: kadenchocluster.s3-us-west-2.amazonaws.com], Response Headers: [x-amz-bucket-region: us-west-2, x-amz-request-id: C926D9B8512D6861, x-amz-id-2: YG5aTPgdO4M6TXb0HPJjXEx8oL1rGZ67lwzuZUNu0Ro34c9UyHtscuHS4TWacRv9GhUIBCZBx4A=, Location: https://kadenchocluster.s3-us-west-2.amazonaws.com/result_%24folder%24, Content-Type: application/xml, Transfer-Encoding: chunked, Date: Thu, 02 Aug 2018 15:28:36 GMT, Server: AmazonS3]
# 18/08/02 15:28:37 WARN RestStorageService: Retrying request following error response: PUT '/result/lesson_2-2_$folder$' -- ResponseCode: 307, ResponseStatus: Temporary Redirect, Request Headers: [Date: Thu, 02 Aug 2018 15:28:37 GMT, Content-Type: binary/octet-stream, Authorization: AWS AKIAJOR7UDIQII6UEAOA:AVfMH+O9ZZTkMPFV/BzJv4NPqA4=, Host: kadenchocluster.s3-us-west-2.amazonaws.com], Response Headers: [x-amz-bucket-region: us-west-2, x-amz-request-id: 51867CEDB28156E3, x-amz-id-2: 0IYHlrHlfdqYizE51Weplu8a6wv4gxbEA8Pv4XdYbiYRbrAt3if4U2WwodK6xzZb+uaErNAn+dM=, Location: https://kadenchocluster.s3-us-west-2.amazonaws.com/result%2Flesson_2-2_%24folder%24, Content-Type: application/xml, Transfer-Encoding: chunked, Date: Thu, 02 Aug 2018 15:28:36 GMT, Server: AmazonS3]
# 18/08/02 15:28:37 WARN RestStorageService: Retrying request following error response: PUT '/result/lesson_2-2/_temporary_$folder$' -- ResponseCode: 307, ResponseStatus: Temporary Redirect, Request Headers: [Date: Thu, 02 Aug 2018 15:28:37 GMT, Content-Type: binary/octet-stream, Authorization: AWS AKIAJOR7UDIQII6UEAOA:QLFQXh7ziFzE7EyXhzzML9o7vAs=, Host: kadenchocluster.s3-us-west-2.amazonaws.com], Response Headers: [x-amz-bucket-region: us-west-2, x-amz-request-id: 6CABA5619173F868, x-amz-id-2: h+4EWHqqtzrGF3hX/69PNQ/l7SivbmVeun06jSTpbrHAS2vGk6G/kEorf3D2JkHDzpOi06ClZCs=, Location: https://kadenchocluster.s3-us-west-2.amazonaws.com/result%2Flesson_2-2%2F_temporary_%24folder%24, Content-Type: application/xml, Transfer-Encoding: chunked, Date: Thu, 02 Aug 2018 15:28:36 GMT, Server: AmazonS3]
# 18/08/02 15:28:38 WARN RestStorageService: Retrying request following error response: PUT '/result/lesson_2-2/_temporary/0_$folder$' -- ResponseCode: 307, ResponseStatus: Temporary Redirect, Request Headers: [Date: Thu, 02 Aug 2018 15:28:37 GMT, Content-Type: binary/octet-stream, Authorization: AWS AKIAJOR7UDIQII6UEAOA:1S9P6Rhy2Kx58hSHf+YhBuNqhF0=, Host: kadenchocluster.s3-us-west-2.amazonaws.com], Response Headers: [x-amz-bucket-region: us-west-2, x-amz-request-id
, Location: https://kadenchocluster.s3-us-west-2.amazonaws.com/result%2Flesson_2-2%2F_temporary%2F0%2Ftask_201808021528_0002_m_000001_%24folder%24, Content-Type: application/xml, Transfer-Encoding: chunked, Date: Thu, 02 Aug 2018 15:28:50 GMT, Server: AmazonS3]
# 18/08/02 15:28:50 WARN RestStorageService: Retrying request following error response: DELETE '/result/lesson_2-2/_temporary/0_$folder$' -- ResponseCode: 307, ResponseStatus: Temporary Redirect, Request Headers: [Date: Thu, 02 Aug 2018 15:28:50 GMT, Authorization: AWS AKIAJOR7UDIQII6UEAOA:pnyR501hVvllJkg30pSSJAdvxZU=, Host: kadenchocluster.s3-us-west-2.amazonaws.com], Response Headers: [x-amz-bucket-region: us-west-2, x-amz-request-id: EECC1DB3283B40C9, x-amz-id-2: zQjQ61TG7vSh6VKBn0cfSBhmqtIvZxwLmY+LwPAQPviMp5iIvRx5yeTRuwaa4BF/MnaP8yo4tNc=, Location: https://kadenchocluster.s3-us-west-2.amazonaws.com/result%2Flesson_2-2%2F_temporary%2F0_%24folder%24, Content-Type: application/xml, Transfer-Encoding: chunked, Date: Thu, 02 Aug 2018 15:28:50 GMT, Server: AmazonS3]
# 18/08/02 15:28:50 WARN RestStorageService: Retrying request following error response: DELETE '/result/lesson_2-2/_temporary_$folder$' -- ResponseCode: 307, ResponseStatus: Temporary Redirect, Request Headers: [Date: Thu, 02 Aug 2018 15:28:50 GMT, Authorization: AWS AKIAJOR7UDIQII6UEAOA:FC9zBS8eiIpLFMXIAXRtr/wCaPA=, Host: kadenchocluster.s3-us-west-2.amazonaws.com], Response Headers: [x-amz-bucket-region: us-west-2, x-amz-request-id: 26C851143830F4F8, x-amz-id-2: 3WJo2sQOG9ohrLrbI05lMCiTl/v0YElUB1UvRmc0JrBFLffRSZEfmdv2HKJHecTYUHJtAMjNvYU=, Location: https://kadenchocluster.s3-us-west-2.amazonaws.com/result%2Flesson_2-2%2F_temporary_%24folder%24, Content-Type: application/xml, Transfer-Encoding: chunked, Date: Thu, 02 Aug 2018 15:28:50 GMT, Server: AmazonS3]
# 18/08/02 15:28:51 WARN RestStorageService: Retrying request following error response: PUT '/result/lesson_2-2/_SUCCESS' -- ResponseCode: 307, ResponseStatus: Temporary Redirect, Request Headers: [Date: Thu, 02 Aug 2018 15:28:51 GMT, Content-MD5: 1B2M2Y8AsgTpgAmY7PhCfg==, Content-Type: binary/octet-stream, x-amz-meta-md5-hash: d41d8cd98f00b204e9800998ecf8427e, Authorization: AWS AKIAJOR7UDIQII6UEAOA:dxjHroqX2UiyL7QdRHx/Z9C/++g=, Host: kadenchocluster.s3-us-west-2.amazonaws.com], Response Headers: [x-amz-bucket-region: us-west-2, x-amz-request-id: D4DDE87A45028F94, x-amz-id-2: 0JOoeMzmF9voJXFV/6V5PxBSJ7MMdpuuEaPJMNhDvlLwP1CUsAxDH5iBdK0j0FpmRy9C3BlMvAc=, Location: https://kadenchocluster.s3-us-west-2.amazonaws.com/result%2Flesson_2-2%2F_SUCCESS, Content-Type: application/xml, Transfer-Encoding: chunked, Date: Thu, 02 Aug 2018 15:28:50 GMT, Server: AmazonS3]
# >>> rdd = sc.wholeTextFiles("s3n://kadenchocluster/gutenberg_dataset/1/8/*/*")
# >>> keys = rdd.map(lambda x: x[0])
# >>> keys.count()
# ```

# %% [markdown]
# - set aws key in ~/.aws/credentials
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ```
# root@ip-172-31-43-195 spark]$ pssh -h conf/slaves "mkdir ~/.aws"
# [1] 15:47:45 [SUCCESS] ec2-34-220-233-164.us-west-2.compute.amazonaws.com
# root@ip-172-31-43-195 spark]$ cat ~/.aws/credentials | pssh -h conf/slaves "cat >> ~/.aws/credentials"
# [1] 15:48:19 [SUCCESS] ec2-34-220-233-164.us-west-2.compute.amazonaws.com
# root@ip-172-31-43-195 spark]$
# ```

# %% [markdown]
# ```
# import boto3
# session = boto3.Session(profile_name='default') # leave out the profile_name argument if you haven't defined profiles
# s3 = boto3.resource('s3')
# bucket = s3.Bucket('BUCKET_NAME')
# objs = bucket.objects.filter(Prefix='gutenberg_dataset/1')
# for obj in objs:
#   print(obj.key)
# ```
